# %% [markdown]
# <div style="text-align: left; margin-bottom: 20px;">
#   <img src="https://umd-brand.transforms.svdcdn.com/production/uploads/images/logos-primary.jpg?w=1801&h=601&auto=compress%2Cformat&fit=crop&dm=1613775207&s=71ce45031f9164cb409f11a2e28d8b8c"
#        alt="UMD Logo" style="max-width: 300px; height: auto;" />
# </div>
#
# # DATA/MSML 641: Natural Language Processing
# ## Session 13: Demo Day, Part 1
#
# **University of Maryland, College Park**
# **Fall 2026**
# **Instructor**: Armin Mehrabian
# **Date**: December 1, 2026

# %% [markdown]
# ## Today
#
# First group of teams present.
#
# **12 minutes each, plus 3 for questions.** The 12-minute limit is firm.
#
# **Final projects were due at 5:00pm today, for every team**, whether you present today or on December 8. Grading is taken from the commit on `main` at that moment.

# %% [markdown]
# ## Running order
#
# | Slot | Time | Team |
# |---|---|---|
# | 1 | 5:05 | |
# | 2 | 5:20 | |
# | 3 | 5:35 | |
# | 4 | 5:50 | |
# | - | 6:05 | break |
# | 5 | 6:15 | |
# | 6 | 6:30 | |
# | 7 | 6:45 | |
#
# *Assigned in Session 11.*

# %% [markdown]
# ## The five areas
#
# | Area | Points |
# |---|---|
# | 1. Problem and users | 10 |
# | 2. Product | 20 |
# | 3. NLP method and evaluation | 25 |
# | 4. User evidence | 15 |
# | 5. Ethics and limitations | 10 |
# | Honest reporting | 5 |
# | Presentation and delivery | 15 |
#
# Full detail in [`project/final-presentation.md`](../project/final-presentation.md).

# %% [markdown]
# ## Two things we are listening for
#
# **Did you measure what you shipped?**
# The model you report numbers for must be the one running in the demo. If they differ, say so and explain why.
#
# **What did not work?**
# A negative result, a loss to your own baseline, a flaw you found in your own evaluation. This is worth 5 points and most teams leave them on the table.

# %% [markdown]
# <div style="text-align: left; margin-bottom: 20px;">
#   <img src="https://umd-brand.transforms.svdcdn.com/production/uploads/images/logos-primary.jpg?w=1801&h=601&auto=compress%2Cformat&fit=crop&dm=1613775207&s=71ce45031f9164cb409f11a2e28d8b8c"
#        alt="UMD Logo" style="max-width: 300px; height: auto;" />
# </div>
#
# # DATA/MSML 641: Natural Language Processing
# ## Lecture 10: Graphs in NLP
#
# **University of Maryland, College Park**
# **Spring 2026**
# **Instructor**: Armin Mehrabian
# **Date**: April 28-29, 2026

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
# 1. Understand graph-based representations in NLP
# 2. Explore knowledge graphs and their applications
# 3. Learn about Graph Neural Networks (GNNs) for NLP tasks
# 4. Apply graph-based methods to semantic parsing and relation extraction

# %% [markdown]
# ## Setup and Imports

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Graph libraries
import networkx as nx

# NLP libraries
import spacy

# Configure plotting
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

print("Setup complete!")

# %% [markdown]
# ## Content Coming Soon
#
# This lecture will cover:
#
# 1. **Knowledge Graphs**
#    - Entity-relation-entity triples
#    - Popular knowledge graphs (Wikidata, DBpedia, Freebase)
#    - Knowledge graph embeddings
#
# 2. **Graph Neural Networks for NLP**
#    - Message passing neural networks
#    - Graph Convolutional Networks (GCN)
#    - Graph Attention Networks (GAT)
#
# 3. **Applications**
#    - Semantic parsing
#    - Relation extraction
#    - Question answering over knowledge graphs
#    - Document-level reasoning

# %% [markdown]
# ## References
#
# - Jurafsky & Martin, Speech and Language Processing, Chapters 13-15
# - Hamilton, W. L. (2020). Graph Representation Learning
# - Kipf, T. N., & Welling, M. (2017). Semi-Supervised Classification with Graph Convolutional Networks

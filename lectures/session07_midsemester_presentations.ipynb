# %% [markdown]
# <div style="text-align: left; margin-bottom: 20px;">
#   <img src="https://umd-brand.transforms.svdcdn.com/production/uploads/images/logos-primary.jpg?w=1801&h=601&auto=compress%2Cformat&fit=crop&dm=1613775207&s=71ce45031f9164cb409f11a2e28d8b8c"
#        alt="UMD Logo" style="max-width: 300px; height: auto;" />
# </div>
#
# # DATA/MSML 641: Natural Language Processing
# ## Session 7: Mid-Semester Project Presentations
#
# **University of Maryland, College Park**
# **Fall 2026**
# **Instructor**: Armin Mehrabian
# **Date**: October 20, 2026

# %% [markdown]
# ## Today
#
# Every team presents. **5 minutes each, plus 2 for questions.**
#
# At 13 teams that is 91 minutes of the 120.
#
# Order is posted below. Rotate your presenter from the mid-semester onward, so it is not the same person on demo day.

# %% [markdown]
# ## Running order
#
# | Slot | Time | Team |
# |---|---|---|
# | 1 | 5:05 | |
# | 2 | 5:12 | |
# | 3 | 5:19 | |
# | 4 | 5:26 | |
# | 5 | 5:33 | |
# | 6 | 5:40 | |
# | 7 | 5:47 | |
# | - | 5:54 | break |
# | 8 | 6:05 | |
# | 9 | 6:12 | |
# | 10 | 6:19 | |
# | 11 | 6:26 | |
# | 12 | 6:33 | |
# | 13 | 6:40 | |
#
# *Fill in from the roster before class.*

# %% [markdown]
# ## Cover these four things
#
# 1. **Demo the MVP.** Show it running. Not slides about it running.
# 2. **What a real user did with it**, and the raw evidence you captured.
# 3. **Your metric**, and where it stands against your baseline.
# 4. **Pivot or persevere**, and why.
#
# Demo over slides. If the demo is not ready, say so plainly and show what is.

# %% [markdown]
# ## How this is graded
#
# Worth **5% of your course grade**.
#
# | | |
# |---|---|
# | A working MVP | Something runs, in front of us |
# | Real user evidence | Someone outside the team used it, and you have the artifact |
# | A clear decision | Pivot or persevere, with the reason |
#
# No written report is due this week. This presentation replaces it.
#
# An honest "this did not work, here is what we learned" scores better than a claim you cannot show.

# %% [markdown]
# ## After today
#
# - Weekly reports resume next session: `reports/session08.md`, due 5:00pm Tuesday October 27
# - Assignment 2 is posted today, due 5:00pm Tuesday November 3
# - Demo day slots are assigned in Session 11 on November 17
#
# Six teaching sessions remain before demo day.

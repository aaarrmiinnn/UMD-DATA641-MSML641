# %% [markdown]
# <div style="text-align: left; margin-bottom: 20px;">
#   <img src="https://umd-brand.transforms.svdcdn.com/production/uploads/images/logos-primary.jpg?w=1801&h=601&auto=compress%2Cformat&fit=crop&dm=1613775207&s=71ce45031f9164cb409f11a2e28d8b8c"
#        alt="UMD Logo" style="max-width: 300px; height: auto;" />
# </div>
#
# # DATA/MSML 641: Natural Language Processing
# ## Session 14: Demo Day, Part 2
#
# **University of Maryland, College Park**
# **Fall 2026**
# **Instructor**: Armin Mehrabian
# **Date**: December 8, 2026

# %% [markdown]
# ## Today
#
# Second group of teams present, then we close the term.
#
# **12 minutes each, plus 3 for questions.**
#
# Submissions closed at 5:00pm on December 1. Teams presenting today present that same submission.

# %% [markdown]
# ## Running order
#
# | Slot | Time | Team |
# |---|---|---|
# | 1 | 5:05 | |
# | 2 | 5:20 | |
# | 3 | 5:35 | |
# | 4 | 5:50 | |
# | - | 6:05 | break |
# | 5 | 6:15 | |
# | 6 | 6:30 | |
#
# *Assigned in Session 11.*

# %% [markdown]
# ## Closing the term
#
# Where the course went:
#
# - Words and meaning, sequences, evaluation
# - Distributed representations, neural networks, transformers
# - Language models, post-training, and how to evaluate them honestly
# - Retrieval, structure, and what is being built on top now
#
# And alongside it, the part that is harder than the modelling: finding a real problem, putting something in front of a real person, and being honest about what came back.

# %% [markdown]
# ## Last session of the term
#
# Last day of classes is Friday December 11.
#
# Grades are posted through ELMS.
#
# Thank you. Go build things.
